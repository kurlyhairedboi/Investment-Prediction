# %% [markdown]
# # Project: Investement Prediction
# * Objective:Study the investement pattern of bank customers to predict whether a new customer will invest or not.

# %%
#for data preparation
import pandas as pd

#for plotting
import matplotlib.pyplot as plt
import seaborn as sns

#for data sampling
from sklearn.model_selection import train_test_split

#for model building
from sklearn.linear_model import LogisticRegression

#for confusion matrix, accuracy, precision, and recall
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
#import data
df=pd.read_csv(r"C:\Users\razee\Desktop\IntroTallent\Python\Data Files used in Projects\Data Files used in Projects\Investment.csv")

# %%
df.shape #(41188 rows, 21 columns)
# Out:
# (41188, 21)

# %%
df.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   44  blue-collar  married           basic.4y  unknown     yes   no
# 1   53   technician  married            unknown       no      no   no
# 2   28   management   single  university.degree       no     yes   no
# 3   39     services  married        high.school       no      no   no
# 4   55      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  cellular   aug         thu  ...         1    999         0  nonexistent
# 1  cellular   nov         fri  ...         1    999         0  nonexistent
# 2  cellular   jun         thu  ...         3      6         2      success
# 3  cellular   apr         fri  ...         2    999         0  nonexistent
# 4  cellular   aug         fri  ...         1      3         1      success
#
#   emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  \
# 0          1.4          93.444          -36.1      4.963       5228.1
# 1         -0.1          93.200          -42.0      4.021       5195.8
# 2         -1.7          94.055          -39.8      0.729       4991.6
# 3         -1.8          93.075          -47.1      1.405       5099.1
# 4         -2.9          92.201          -31.4      0.869       5076.2
#
#    Invested
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#
# [5 rows x 21 columns]

# %%
#Replace Yes wiht 1 and No with 0 in Invested column
df['Invested']=df['Invested'].replace(['Yes','No'],[1,0])

# %%
df.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   44  blue-collar  married           basic.4y  unknown     yes   no
# 1   53   technician  married            unknown       no      no   no
# 2   28   management   single  university.degree       no     yes   no
# 3   39     services  married        high.school       no      no   no
# 4   55      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  cellular   aug         thu  ...         1    999         0  nonexistent
# 1  cellular   nov         fri  ...         1    999         0  nonexistent
# 2  cellular   jun         thu  ...         3      6         2      success
# 3  cellular   apr         fri  ...         2    999         0  nonexistent
# 4  cellular   aug         fri  ...         1      3         1      success
#
#   emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  \
# 0          1.4          93.444          -36.1      4.963       5228.1
# 1         -0.1          93.200          -42.0      4.021       5195.8
# 2         -1.7          94.055          -39.8      0.729       4991.6
# 3         -1.8          93.075          -47.1      1.405       5099.1
# 4         -2.9          92.201          -31.4      0.869       5076.2
#
#    Invested
# 0         0
# 1         0
# 2         1
# 3         0
# 4         1
#
# [5 rows x 21 columns]

# %%
#dtypes
df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp_var_rate      float64
# cons_price_idx    float64
# cons_conf_idx     float64
# euribor3m         float64
# nr_employed       float64
# Invested            int64
# dtype: object

# %%
#check missing values
df.isnull().sum() #No missing values
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# Invested          0
# dtype: int64

# %%
#Outliers
plt.boxplot(df['age']) # has outliers
plt.show()

# %%
#Outliers
plt.boxplot(df['cons_conf_idx']) # has outliers
plt.show()

# %%
#Outliers
plt.boxplot(df['emp_var_rate']) # no outliers
plt.show()

# %%
#Outliers
plt.boxplot(df['euribor3m']) # no outliers
plt.show()

# %%
#Outliers
plt.boxplot(df['duration'])
plt.show()

# %%
plt.boxplot(df['cons_price_idx'])
plt.show()

# %%
#user defined function for outlier treatment
def remove_outlier(d,c):
    q1=d[c].quantile(0.25)
    q3=d[c].quantile(0.75)
    
    iqr=q3-q1
    
    ub=q3+1.5*iqr
    lb=q1-1.5*iqr
    
    output=d[(d[c]>lb) & (d[c]<ub)]
    return output

# %%
#remove outliers from Age and cons_conf_idx

# %%
df=remove_outlier(df,'age')
plt.boxplot(df['age'])
plt.show()

# %%
df=remove_outlier(df,'cons_conf_idx')
plt.boxplot(df['cons_conf_idx'])
plt.show()

# %%
df=remove_outlier(df,'duration')
plt.boxplot(df['duration'])
plt.show()

# %% [markdown]
# # Check values in categorical variable to ensure there is no issue

# %%
df['job'].unique()
# Out:
# array(['blue-collar', 'technician', 'management', 'services', 'retired',
#        'admin.', 'housemaid', 'unemployed', 'entrepreneur',
#        'self-employed', 'unknown', 'student'], dtype=object)

# %%
df['marital'].unique()
# Out:
# array(['married', 'single', 'divorced', 'unknown'], dtype=object)

# %%
df['education'].unique()
# Out:
# array(['basic.4y', 'unknown', 'university.degree', 'high.school',
#        'basic.9y', 'professional.course', 'basic.6y', 'illiterate'],
#       dtype=object)

# %%
#Replace basic.4y, basic.6y, and basic.9y with "basic"

# %%
df['education']=df['education'].replace(['basic.4y','basic.6y','basic.9y'],
                                        ['basic','basic','basic'])

# %%
df['education'].unique()
# Out:
# array(['basic', 'unknown', 'university.degree', 'high.school',
#        'professional.course', 'illiterate'], dtype=object)

# %%
df['default'].unique()
# Out:
# array(['unknown', 'no', 'yes'], dtype=object)

# %%
df['housing'].unique()
# Out:
# array(['yes', 'no', 'unknown'], dtype=object)

# %%
df['loan'].unique()
# Out:
# array(['no', 'yes', 'unknown'], dtype=object)

# %%
df['contact'].unique()
# Out:
# array(['cellular', 'telephone'], dtype=object)

# %%
df['month'].unique()
# Out:
# array(['aug', 'nov', 'jun', 'apr', 'jul', 'may', 'mar', 'sep', 'oct',
#        'dec'], dtype=object)

# %%
df['day_of_week'].unique()
# Out:
# array(['thu', 'fri', 'tue', 'mon', 'wed'], dtype=object)

# %%
df['poutcome'].unique()
# Out:
# array(['nonexistent', 'success', 'failure'], dtype=object)

# %% [markdown]
# # ------------ EDA Starts --------------

# %%
#all plots
sns.pairplot(df)

# %% [markdown]
# # distribution

# %%
sns.distplot(df['age'])
plt.show()
# Out:
# C:\Users\razee\AppData\Local\Temp\ipykernel_3052\2799180019.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])

# %%
sns.distplot(df['duration'])
plt.show()
# Out:
# C:\Users\razee\AppData\Local\Temp\ipykernel_3052\1710870456.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['duration'])

# %%
sns.distplot(df['emp_var_rate'])
plt.show()
# Out:
# C:\Users\Mukesh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Data mix

# %%
df.groupby('Invested')['Invested'].count().plot(kind='bar')
#imbalanced class
# Out:
# <Axes: xlabel='Invested'>

# %%
#correlation plot
df_numeric=df.select_dtypes(include=['int64', 'float64'])
df_numeric.head()
# Out:
#    age  duration  campaign  pdays  previous  emp_var_rate  cons_price_idx  \
# 0   44       210         1    999         0           1.4          93.444
# 1   53       138         1    999         0          -0.1          93.200
# 2   28       339         3      6         2          -1.7          94.055
# 3   39       185         2    999         0          -1.8          93.075
# 4   55       137         1      3         1          -2.9          92.201
#
#    cons_conf_idx  euribor3m  nr_employed  Invested
# 0          -36.1      4.963       5228.1         0
# 1          -42.0      4.021       5195.8         0
# 2          -39.8      0.729       4991.6         1
# 3          -47.1      1.405       5099.1         0
# 4          -31.4      0.869       5076.2         1

# %%
#remove categorical variables
df_numeric=df_numeric.drop(['campaign','pdays','previous'], axis=1)

# %%
#df_numeric.head()

# %%
#heatmap
sns.heatmap(df_numeric.corr(), cmap='YlGnBu', annot=True)
# Out:
# <Axes: >

# %%
#drop unwanted columns #, 'duration'
col_to_drop=['contact', 'month', 'day_of_week', 'campaign', 
             'pdays','previous', 'poutcome']

# %%
df=df.drop(col_to_drop, axis=1)

# %%
#One-hot-encoding (dummy conversion)
df_categorical=df.select_dtypes(include='object')
df_categorical
# Out:
#                job  marital          education  default housing loan
# 0      blue-collar  married              basic  unknown     yes   no
# 1       technician  married            unknown       no      no   no
# 2       management   single  university.degree       no     yes   no
# 3         services  married        high.school       no      no   no
# 4          retired  married              basic       no     yes   no
# ...            ...      ...                ...      ...     ...  ...
# 41182       admin.  married        high.school       no     yes   no
# 41183      retired  married        high.school  unknown      no  yes
# 41184    housemaid  married              basic  unknown      no   no
# 41185       admin.   single  university.degree  unknown     yes  yes
# 41187      student   single        high.school       no      no   no
#
# [35350 rows x 6 columns]

# %% [markdown]
# Why do we drop the 1st column after converting dummies?
#
# The first column represents the absence of any category and is redundant because the absence of any category is already represented by the absence of all other categories. Therefore, dropping the first column after one hot encoding helps to reduce the dimensionality of the data without losing any valuable information. Additionally, dropping the first column also helps to prevent multicollinearity, which is a statistical problem that can arise when there are highly correlated independent variables.

# %%
#create dummies
df_dummies=pd.get_dummies(df_categorical, drop_first=True)
df_dummies.head()
# Out:
#    job_blue-collar  job_entrepreneur  job_housemaid  job_management  \
# 0             True             False          False           False
# 1            False             False          False           False
# 2            False             False          False            True
# 3            False             False          False           False
# 4            False             False          False           False
#
#    job_retired  job_self-employed  job_services  job_student  job_technician  \
# 0        False              False         False        False           False
# 1        False              False         False        False            True
# 2        False              False         False        False           False
# 3        False              False          True        False           False
# 4         True              False         False        False           False
#
#    job_unemployed  ...  education_illiterate  education_professional.course  \
# 0           False  ...                 False                          False
# 1           False  ...                 False                          False
# 2           False  ...                 False                          False
# 3           False  ...                 False                          False
# 4           False  ...                 False                          False
#
#    education_university.degree  education_unknown  default_unknown  \
# 0                        False              False             True
# 1                        False               True            False
# 2                         True              False            False
# 3                        False              False            False
# 4                        False              False            False
#
#    default_yes  housing_unknown  housing_yes  loan_unknown  loan_yes
# 0        False            False         True         False     False
# 1        False            False        False         False     False
# 2        False            False         True         False     False
# 3        False            False        False         False     False
# 4        False            False         True         False     False
#
# [5 rows x 25 columns]

# %%
#Create final data
df_final=pd.concat([df_numeric,df_dummies], axis=1)
df_final.head()
# Out:
#    age  duration  emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  \
# 0   44       210           1.4          93.444          -36.1      4.963
# 1   53       138          -0.1          93.200          -42.0      4.021
# 2   28       339          -1.7          94.055          -39.8      0.729
# 3   39       185          -1.8          93.075          -47.1      1.405
# 4   55       137          -2.9          92.201          -31.4      0.869
#
#    nr_employed  Invested  job_blue-collar  job_entrepreneur  ...  \
# 0       5228.1         0             True             False  ...
# 1       5195.8         0            False             False  ...
# 2       4991.6         1            False             False  ...
# 3       5099.1         0            False             False  ...
# 4       5076.2         1            False             False  ...
#
#    education_illiterate  education_professional.course  \
# 0                 False                          False
# 1                 False                          False
# 2                 False                          False
# 3                 False                          False
# 4                 False                          False
#
#    education_university.degree  education_unknown  default_unknown  \
# 0                        False              False             True
# 1                        False               True            False
# 2                         True              False            False
# 3                        False              False            False
# 4                        False              False            False
#
#    default_yes  housing_unknown  housing_yes  loan_unknown  loan_yes
# 0        False            False         True         False     False
# 1        False            False        False         False     False
# 2        False            False         True         False     False
# 3        False            False        False         False     False
# 4        False            False         True         False     False
#
# [5 rows x 33 columns]

# %%
#export prepared data to excel so that we can have a look and verify that there are only numeric columns
#df_final.to_excel(r"C:\Users\Mukesh\Desktop\Investment_final_data.xlsx")

# %%
#Create x and y
x=df_final.drop('Invested', axis=1)
y=df_final['Invested']

# %%
#check x and y
print(x.shape, y.shape)
# Out:
# (35350, 32) (35350,)

# %% [markdown]
# # Feature Selection

# %% [markdown]
# # Create training and test samples

# %%
xtrain, xtest, ytrain, ytest=train_test_split(x,y, test_size=0.3, 
                                              random_state=999)

# %%
#check sample size
print(xtrain.shape, xtest.shape, ytrain.shape, ytest.shape)
# Out:
# (24745, 32) (10605, 32) (24745,) (10605,)

# %% [markdown]
# # Feature Selection using Chi-square test

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

key_features = SelectKBest(score_func=f_classif, k=4) 
#to select 5 significant features

# Fit the key_features to the training data and transform it
xtrain_selected = key_features.fit_transform(xtrain, ytrain)

# Get the indices of the selected features
selected_indices = key_features.get_support(indices=True)

# Get the names of the selected features
selected_features = xtrain.columns[selected_indices]

# %%
selected_indices
# Out:
# array([1, 2, 5, 6], dtype=int64)

# %%
#Create x_train based on selected features
x_train=xtrain[selected_features]

# %%
x_train.columns
# Out:
# Index(['duration', 'emp_var_rate', 'euribor3m', 'nr_employed'], dtype='object')

# %%
#Store KBest columns from xtest to x_test
x_test=xtest[selected_features]

# %% [markdown]
# # Logistic Regression Algorithm

# %%
#instantiate Logistic Regression
logreg=LogisticRegression()

# %% [markdown]
# # Model 1: Build a model using all features

# %%
#train the model
logreg.fit(xtrain,ytrain)
# Out:
# C:\Users\razee\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#check training accuracy
logreg.score(xtrain,ytrain)
#accuracy= 0.9125336545274196
# Out:
# 0.9483532026672055

# %%
y_pred=logreg.predict(xtest)

# %%
#check prediction accuracy
logreg.score(xtest,ytest)
#accuracy= 0.9113149847094801
# Out:
# 0.9476661951909476

# %% [markdown]
# # Model 2: Using selected K(4) Best variables

# %% [markdown]
# * Built a model with 5 variables, Accuracy was 0.91
# * Built another model with 4 variables, Accuracy was 0.90 hence continued with k=4

# %%
#Train the model using xtrain and ytrain (fit the model)
logreg.fit(x_train,ytrain)
# Out:
# LogisticRegression()

# %%
logreg.score(x_train,ytrain)
# Out:
# 0.9386542735906244

# %%
#predict investement using test data
lr_predicted=logreg.predict(x_test)

# %%
logreg.score(x_test,ytest)
# Out:
# 0.9385195662423386

# %%
#print confusino matrix
confusion_matrix(ytest, lr_predicted)
# Out:
# array([[9858,   89],
#        [ 563,   95]], dtype=int64)

# %%
(9858+95)/(9858+89+95+563)
# Out:
# 0.9385195662423386

# %% [markdown]
# # Score to check Model Performance
# * Accuracy=(TN+TP)/(TN+TP+FN+FP)
#
# * Precision=TP/(TP+FP)
#
#
# * Recall=TP/(TP+FN)
#
# * F-score=2xPrecisionxRecall/(Precision+Recall)

# %%
#store logistic regression scores in seperate variables
lr_accuracy=accuracy_score(ytest, lr_predicted)
lr_precision=precision_score(ytest, lr_predicted)
lr_recall=recall_score(ytest, lr_predicted)
lr_fscore=f1_score(ytest, lr_predicted)

# %%
col=['Model','Accuracy',  'Precision','Recall', 'F1-Score']
data=[["Log Reg", lr_accuracy,lr_precision, lr_recall,lr_fscore]]
ml_summary=pd.DataFrame(data, columns=col)
ml_summary
# Out:
#      Model  Accuracy  Precision    Recall  F1-Score
# 0  Log Reg   0.93852   0.516304  0.144377  0.225653

# %% [markdown]
# # KNN (K-nearest neighbors) Algorithm

# %%
#import knn library from sklearn
from sklearn.neighbors import KNeighborsClassifier

# %%
#Create model object
knn=KNeighborsClassifier(n_neighbors=9, metric='euclidean')

# %%
#fit knn model
knn.fit(x_train, ytrain)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=7)

# %%
#predict y using knn
knn_predicted=knn.predict(x_test)

# %%
#check scores
knn_accuracy=accuracy_score(ytest, knn_predicted)
knn_precision=precision_score(ytest, knn_predicted)
knn_recall=recall_score(ytest, knn_predicted)
knn_fscore=f1_score(ytest, knn_predicted)

# %%
#update accuracy tables
col=['Model','Accuracy',  'Precision','Recall', 'F1-Score']
data=[["Log Reg", lr_accuracy,lr_precision, lr_recall,lr_fscore],
     ["KNN", knn_accuracy,knn_precision, knn_recall,knn_fscore]]
ml_summary=pd.DataFrame(data, columns=col)
ml_summary
# Out:
#      Model  Accuracy  Precision    Recall  F1-Score
# 0  Log Reg   0.93852   0.516304  0.144377  0.225653
# 1      KNN   0.94644   0.603211  0.399696  0.480804

# %% [markdown]
# # Naive Bayes Algorithm

# %%
#Import Gaussian Naive Bayes model
from sklearn.naive_bayes import GaussianNB

# %%
#Create a Gaussian Classifier
gnb = GaussianNB()

# %%
# Train the model using the training sets
gnb.fit(x_train,ytrain)
# Out:
# GaussianNB()

# %%
#Predict Output
gnb_predicted = gnb.predict(x_test)

# %%
#check scores
gnb_accuracy=accuracy_score(ytest, gnb_predicted)
gnb_precision=precision_score(ytest, gnb_predicted)
gnb_recall=recall_score(ytest, gnb_predicted)
gnb_fscore=f1_score(ytest, gnb_predicted)

# %%
# update accuracy tables
col=['Model','Accuracy',  'Precision','Recall', 'F1-Score']
data=[["Log Reg", lr_accuracy,lr_precision, lr_recall,lr_fscore],
     ["KNN", knn_accuracy,knn_precision, knn_recall,knn_fscore],
     ["Naive Bayes", gnb_accuracy,gnb_precision, gnb_recall,gnb_fscore]]
ml_summary=pd.DataFrame(data, columns=col)
ml_summary
# Out:
#          Model  Accuracy  Precision    Recall  F1-Score
# 0      Log Reg  0.938520   0.516304  0.144377  0.225653
# 1          KNN  0.946440   0.603211  0.399696  0.480804
# 2  Naive Bayes  0.821782   0.243119  0.886018  0.381545

# %% [markdown]
# # Decision Tree Classifier

# %%
#import Decision Tree classifier library from sklearn
from sklearn.tree import DecisionTreeClassifier

# %%
#Create model object
dtree=DecisionTreeClassifier(max_depth=5)

# %%
#fit the training model
dtree.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
#test the model using xtest
dtree_predicted=dtree.predict(xtest)

# %%
#Codes to print a sample tree based on model (max_depth=3 is ideal to see the tree)
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

fig = plt.figure(figsize=((25,20)))
plot_tree(dtree,
            feature_names =xtest.columns,
            class_names=['No', 'Yes'], 
            impurity=False,
            proportion=False,
            filled=True)
plt.show()
#fig.savefig('test.png')

# %%
#check scores
dtree_accuracy=accuracy_score(ytest, dtree_predicted)
dtree_precision=precision_score(ytest, dtree_predicted)
dtree_recall=recall_score(ytest, dtree_predicted)
dtree_fscore=f1_score(ytest, dtree_predicted)

# %%
# update accuracy tables
col=['Model','Accuracy',  'Precision','Recall', 'F1-Score']
data=[["Log Reg", lr_accuracy,lr_precision, lr_recall,lr_fscore],
     ["KNN", knn_accuracy,knn_precision, knn_recall,knn_fscore],
     ["Naive Bayes", gnb_accuracy,gnb_precision, gnb_recall,gnb_fscore],
     ["Decision Tree", dtree_accuracy,dtree_precision, dtree_recall,dtree_fscore]]
ml_summary=pd.DataFrame(data, columns=col)
ml_summary
# Out:
#            Model  Accuracy  Precision    Recall  F1-Score
# 0        Log Reg  0.938520   0.516304  0.144377  0.225653
# 1            KNN  0.946440   0.603211  0.399696  0.480804
# 2    Naive Bayes  0.821782   0.243119  0.886018  0.381545
# 3  Decision Tree  0.953135   0.630894  0.589666  0.609584

# %% [markdown]
# # Random Forest Classifier

# %%
#import Random Forest classifier library from sklearn
from sklearn.ensemble import RandomForestClassifier

# %%
# creating a RF classifier
rfc = RandomForestClassifier(n_estimators = 100)

# %%
rfc.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
rfc_predicted=rfc.predict(xtest)

# %%
#check scores
rfc_accuracy=accuracy_score(ytest, rfc_predicted)
rfc_precision=precision_score(ytest, rfc_predicted)
rfc_recall=recall_score(ytest, rfc_predicted)
rfc_fscore=f1_score(ytest, rfc_predicted)

# %%
# update accuracy tables
col=['Model','Accuracy',  'Precision','Recall', 'F1-Score']
data=[["Log Reg", lr_accuracy,lr_precision, lr_recall,lr_fscore],
     ["KNN", knn_accuracy,knn_precision, knn_recall,knn_fscore],
     ["Naive Bayes", gnb_accuracy,gnb_precision, gnb_recall,gnb_fscore],
     ["Decision Tree", dtree_accuracy,dtree_precision, dtree_recall,dtree_fscore],
     ["Random Forest", rfc_accuracy,rfc_precision, rfc_recall,rfc_fscore]]
ml_summary=pd.DataFrame(data, columns=col)
ml_summary
# Out:
#            Model  Accuracy  Precision    Recall  F1-Score
# 0        Log Reg  0.938520   0.516304  0.144377  0.225653
# 1            KNN  0.944460   0.573876  0.407295  0.476444
# 2    Naive Bayes  0.821782   0.243119  0.886018  0.381545
# 3  Decision Tree  0.953135   0.630894  0.589666  0.609584
# 4  Random Forest  0.949269   0.626582  0.451368  0.524735

# %% [markdown]
# # SVM (Support Vector Machine) Algorithm

# %%
#Support Vector Machine (SVC: Support Vector Classifier)
from sklearn.svm import SVC

# %%
#create an instance of SVM
svm = SVC(kernel='linear')

# %%
#Fit the model
svm.fit(x_train,ytrain)
# Out:
# SVC(kernel='linear')

# %%
#Predict the response from xtest
svm_predicted=svm.predict(x_test)

# %%
#check scores
svm_accuracy=accuracy_score(ytest, svm_predicted)
svm_precision=precision_score(ytest, svm_predicted)
svm_recall=recall_score(ytest, svm_predicted)
svm_fscore=f1_score(ytest, svm_predicted)

# %%
# update accuracy tables
col=['Model','Accuracy',  'Precision','Recall', 'F1-Score']
data=[["Log Reg", lr_accuracy,lr_precision, lr_recall,lr_fscore],
     ["KNN", knn_accuracy,knn_precision, knn_recall,knn_fscore],
     ["Naive Bayes", gnb_accuracy,gnb_precision, gnb_recall,gnb_fscore],
     ["Decision Tree", dtree_accuracy,dtree_precision, dtree_recall,dtree_fscore],
     ["Random Forest", rfc_accuracy,rfc_precision, rfc_recall,rfc_fscore],
     ["SVM", svm_accuracy,svm_precision, svm_recall,svm_fscore]]
ml_summary=pd.DataFrame(data, columns=col)
ml_summary
# Out:
#            Model  Accuracy  Precision    Recall  F1-Score
# 0        Log Reg  0.938520   0.516304  0.144377  0.225653
# 1            KNN  0.944460   0.573876  0.407295  0.476444
# 2    Naive Bayes  0.821782   0.243119  0.886018  0.381545
# 3  Decision Tree  0.953135   0.630894  0.589666  0.609584
# 4  Random Forest  0.949269   0.626582  0.451368  0.524735
# 5            SVM  0.939745   0.552486  0.151976  0.238379

# %%
#implementtion

# %%
#We have finalized Decision tree algorithm based F1 Score.

# %% [markdown]
# # Next Step
# * 1) Ask your client to provide the data of new "Bank customers"
# * 2) After receiving the new data (that will have the same format like your training data/Investment data), import the new data as new_df.
# * 3) in the new_df, chck missing value, outliers, and perform encoding.
# * 4) Now predict the output sing the code below:
# investment_prediction=dtree.predict(new_df)
# * 5) Export the output from investment_prediction to excel.
# * 6) Add the output in the last column of new data.
# * 7) Share with your client. Your client will validate the output for 3 to 6 months and send you the report.

# %%
#import new data
new_df=pd.read_excel()

# %%
#check missing values and impute

# %%
#dummy conversion

# %%
#createa new_final by combining dummy and numeric

# %%
#predict y by using the best model
predict_investment=dtree.predict(new_final)
